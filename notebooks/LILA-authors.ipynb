# %%
import json
import sys
import os
import re
import pandas as pd
from definitions import ROOT_DIR

# Add src directory to sys.path
# Adapted from Taras Alenin's answer on StackOverflow at:
# https://stackoverflow.com/a/55623567
src_path = os.path.join(ROOT_DIR, 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

from author_getter import get_unique_author_strings

# %%
data_path = os.path.join(ROOT_DIR, 'data')
lila_letters_metadata = os.path.join(
    data_path,
    'original/LILA_imposters/metadata')


get_unique_author_strings(lila_letters_metadata)
# Out:
#                                                 title  \
# 0   Augusta County: Jedediah Hotchkiss to Sara A. ...
# 0   Freedmen's Bureau Records: Thomas P. Jackson t...
# 0   Augusta County: L. M. Blackford to Wm. M. Blac...
# 0   Freedmen's Bureau Records: Thomas P. Jackson t...
# 0   Augusta County: Jedediah Hotchkiss to Sara A. ...
# ..                                                ...
# 0   Augusta County: William L. Coan to Samuel Hunt...
# 0   Augusta County: William S. Eskridge to John Mc...
# 0   Freedmen's Bureau Records: W. Storer How to Or...
# 0   Augusta: William F. Brand to Kate Armentrout, ...
# 0   Augusta County: Geraldine McGuffin to John B. ...
#
#                                               summary  \
# 0   Hotchkiss writes of his appointment as Acting ...
# 0   Jackson's letter to Manly states that John Sco...
# 0   Blackford tells a family member about his comp...
# 0   Jackson asks Martha Ryan if she has any inform...
# 0   Hotchkiss comments on affairs at home, food in...
# ..                                                ...
# 0   Coan discusses an imminent excursion to Lexing...
# 0   William S. Eskridge complains about political ...
# 0
# 0   Brand tells Kate about her friends in the army...
# 0   Geraldine McGuffin writes to her cousin John M...
#
#                                              keywords  \
# 0   Family, Military Authority, Slavery, African A...
# 0    Education, Aid/Relief, Women, American Civil War
# 0   Troop Movement, Family, Women, Military Author...
# 0                          Family, American Civil War
# 0   Women, Home Front, Battle Description, America...
# ..                                                ...
# 0   African Americans, Education, Women, American ...
# 0        State Goverment, Slavery, American Civil War
# 0   Administration/Bureaucracy, Aid/Relief, Health...
# 0   Camp Life, Church/Religious Activity, Patrioti...
# 0              Family, Home Front, American Civil War
#
#                                           source_file           content_file  \
# 0   api.valley.newamericanhistory.org/storage/data...  content/p009_049.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p033_006.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p014_033.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p032_006.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p015_033.html
# ..                                                ...                    ...
# 0   api.valley.newamericanhistory.org/storage/data...  content/p022_035.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p004_000.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p023_035.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p007_009.html
# 0   api.valley.newamericanhistory.org/storage/data...  content/p006_009.html
#
#        local_file              author
# 0   p009_049.json  jedediah_hotchkiss
# 0   p033_006.json      thomas_jackson
# 0   p014_033.json         l_blackford
# 0   p032_006.json      thomas_jackson
# 0   p015_033.json  jedediah_hotchkiss
# ..            ...                 ...
# 0   p022_035.json        william_coan
# 0   p004_000.json    william_eskridge
# 0   p023_035.json               w_how
# 0   p007_009.json       william_brand
# 0   p006_009.json  geraldine_mcguffin
#
# [2033 rows x 7 columns]
